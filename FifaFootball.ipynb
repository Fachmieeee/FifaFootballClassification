# %% [markdown]
# <a href="https://colab.research.google.com/github/Fachmieeee/FifaFootballClassification/blob/master/FifaFootball.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10, 6

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
dataset = pd.read_csv('/content/gdrive/My Drive/AirPassengers/data.csv')

# %%
dataset.head(20)
# Out:
#     Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0            0  158023  ...        8.0         €226.5M
# 1            1   20801  ...       11.0         €127.1M
# 2            2  190871  ...       11.0         €228.1M
# 3            3  193080  ...       94.0         €138.6M
# 4            4  192985  ...       13.0         €196.4M
# 5            5  183277  ...        8.0         €172.1M
# 6            6  177003  ...        9.0         €137.4M
# 7            7  176580  ...       37.0           €164M
# 8            8  155862  ...       11.0         €104.6M
# 9            9  200389  ...       89.0         €144.5M
# 10          10  188545  ...       10.0         €127.1M
# 11          11  182521  ...       10.0         €156.8M
# 12          12  182493  ...       15.0          €90.2M
# 13          13  168542  ...       12.0           €111M
# 14          14  215914  ...       10.0         €121.3M
# 15          15  211110  ...        8.0         €153.5M
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
# Unnamed: 0                  18207 non-null int64
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# ...

# %%
dataset.describe()
# Out:
#          Unnamed: 0             ID  ...  GKPositioning    GKReflexes
# count  18207.000000   18207.000000  ...   18159.000000  18159.000000
# mean    9103.000000  214298.338606  ...      16.388898     16.710887
# std     5256.052511   29965.244204  ...      17.034669     17.955119
# min        0.000000      16.000000  ...       1.000000      1.000000
# 25%     4551.500000  200315.500000  ...       8.000000      8.000000
# 50%     9103.000000  221759.000000  ...      11.000000     11.000000
# 75%    13654.500000  236529.500000  ...      14.000000     14.000000
# max    18206.000000  246620.000000  ...      90.000000     94.000000
#
# [8 rows x 44 columns]

# %%
dataset.dtypes
# Out:
# Unnamed: 0                    int64
# ID                            int64
# Name                         object
# Age                           int64
# Photo                        object
# Nationality                  object
# Flag                         object
# Overall                       int64
# Potential                     int64
# Club                         object
# Club Logo                    object
# Value                        object
# Wage                         object
# Special                       int64
# Preferred Foot               object
# International Reputation    float64
# Weak Foot                   float64
# Skill Moves                 float64
# Work Rate                    object
# Body Type                    object
# Real Face                    object
# Position                     object
# Jersey Number               float64
# Joined                       object
# Loaned From                  object
# Contract Valid Until         object
# ...

# %%
dataset.shape
# Out:
# (18207, 89)

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0                      0
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Special                         0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Real Face                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# ...

# %%
label = []
for i in range(len(dataset)):
    if (dataset['Overall'][i] >= 90) :
        label.append('A')
    elif  80<= dataset['Overall'][i] < 90 :
        label.append('B')
    elif  70<= dataset['Overall'][i] < 80 :
        label.append('C')
    elif  60<= dataset['Overall'][i] < 70 :
        label.append('D')
    else:
        label.append('E')

# %%
dataset ['label'] = label
dataset.head(20)
# Out:
#     Unnamed: 0      ID               Name  ...  GKReflexes Release Clause label
# 0            0  158023           L. Messi  ...         8.0        €226.5M     A
# 1            1   20801  Cristiano Ronaldo  ...        11.0        €127.1M     A
# 2            2  190871          Neymar Jr  ...        11.0        €228.1M     A
# 3            3  193080             De Gea  ...        94.0        €138.6M     A
# 4            4  192985       K. De Bruyne  ...        13.0        €196.4M     A
# 5            5  183277          E. Hazard  ...         8.0        €172.1M     A
# 6            6  177003          L. Modrić  ...         9.0        €137.4M     A
# 7            7  176580          L. Suárez  ...        37.0          €164M     A
# 8            8  155862       Sergio Ramos  ...        11.0        €104.6M     A
# 9            9  200389           J. Oblak  ...        89.0        €144.5M     A
# 10          10  188545     R. Lewandowski  ...        10.0        €127.1M     A
# ...

# %%
dataset.groupby('label').size()
# Out:
# label
# A      14
# B     541
# C    5083
# D    9665
# E    2904
# dtype: int64

# %%
label_a = dataset[dataset['label']=='A']
label_a = label_a[['Name','Overall','label']]
label_a.head()
# Out:
#                 Name  Overall label
# 0           L. Messi       94     A
# 1  Cristiano Ronaldo       94     A
# 2          Neymar Jr       92     A
# 3             De Gea       91     A
# 4       K. De Bruyne       91     A

# %%
label_b = dataset[dataset['label']=='B']
label_b = label_b[['Name','Overall','label']]
label_b.head()
# Out:
#              Name  Overall label
# 14       N. Kanté       89     B
# 15      P. Dybala       89     B
# 16        H. Kane       89     B
# 17   A. Griezmann       89     B
# 18  M. ter Stegen       89     B

# %%
label_c = dataset[dataset['label']=='C']
label_c = label_c[['Name','Overall','label']]
label_c.head()
# Out:
#              Name  Overall label
# 555  V. Tsygankov       79     C
# 556    Rúben Dias       79     C
# 557   David Neres       79     C
# 558      Raphinha       79     C
# 559      A. Harit       79     C

# %%
label_d = dataset[dataset['label']=='D']
label_d = label_d[['Name','Overall','label']]
label_d.head()
# Out:
#                Name  Overall label
# 5638    R. Abdullah       69     D
# 5639     M. Ordóñez       69     D
# 5640   L. Robertone       69     D
# 5641      I. Mathew       69     D
# 5642  P. Velthuizen       69     D

# %%
plt.plot(label_a['Overall'],'ro')
plt.plot(label_b['Overall'],'bo')
plt.plot(label_c['Overall'],'yo')
plt.plot(label_d['Overall'],'go')

# %%
x = dataset[['Overall']]
x.head()
# Out:
#    Overall
# 0       94
# 1       94
# 2       92
# 3       91
# 4       91

# %%
y = dataset['label']
y.head()
# Out:
# 0    A
# 1    A
# 2    A
# 3    A
# 4    A
# Name: label, dtype: object

# %%
import pandas_profiling as pp

# %%
pp.ProfileReport(dataset)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
dataset.head(10)
# Out:
#    Unnamed: 0      ID               Name  ...  GKReflexes Release Clause label
# 0           0  158023           L. Messi  ...         8.0        €226.5M     A
# 1           1   20801  Cristiano Ronaldo  ...        11.0        €127.1M     A
# 2           2  190871          Neymar Jr  ...        11.0        €228.1M     A
# 3           3  193080             De Gea  ...        94.0        €138.6M     A
# 4           4  192985       K. De Bruyne  ...        13.0        €196.4M     A
# 5           5  183277          E. Hazard  ...         8.0        €172.1M     A
# 6           6  177003          L. Modrić  ...         9.0        €137.4M     A
# 7           7  176580          L. Suárez  ...        37.0          €164M     A
# 8           8  155862       Sergio Ramos  ...        11.0        €104.6M     A
# 9           9  200389           J. Oblak  ...        89.0        €144.5M     A
#
# [10 rows x 90 columns]

# %%
plt.figure(figsize=(10,8))
sns.countplot(dataset['label'].sort_values()) #0==Female and 1=Male

# %%
plt.figure(figsize=(10,8))
sns.countplot(dataset['label'].sort_values(), hue=dataset['Preferred Foot'])

# %%
plt.figure(figsize=(8,6))
dataset.groupby('Position')['Overall'].mean().plot()

# %%
plt.figure(figsize=(10,8))
sns.countplot(dataset['label'].sort_values(), hue=dataset['Position'])

# %%
sns.boxplot(x="Overall", y="Position", data=dataset)

# %%
dataset = dataset.dropna()
print(dataset.shape)
# Out:
# (0, 90)

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-144-85db0b78622c> in <module>()
# ----> 1 dataset.shape(1)
#
# TypeError: 'tuple' object is not callable
